# %% [markdown]
# <center> <h1 style="color : #483D8B"> Analisis sobre Seguridad Aerea </h1> </center>
# <center> <h2 style="color : #4682B4"> Proyecto Final </h2> </center>
#
# <center> <h3 style="color : #FF4500"> Curso Visualizacion de Datos </h3> </center>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mplt

# %%
cols = ["airline", "avail_seat_km_per_week", "incidents_85_99", "fatal_accidents_85_99", "fatalities_85_99", "incidents_00_14", "fatal_accidents_00_14", "fatalities_00_14"]

avSafety = pd.read_csv("Aviation safety.csv", names=cols)

# %%
avSafety
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 0                      airline  avail_seat_km_per_week  incidents_85_99
# 1                   Aer Lingus               320906734                2
# 2                    Aeroflot*              1197672318               76
# 3        Aerolineas Argentinas               385803648                6
# 4                  Aeromexico*               596871813                3
# 5                   Air Canada              1865253802                2
# 6                   Air France              3004002661               14
# 7                   Air India*               869253552                2
# 8             Air New Zealand*               710174817                3
# 9             Alaska Airlines*               965346773                5
# 10                    Alitalia               698012498                7
# 11          All Nippon Airways              1841234177                3
# ...

# %%
avSafety.drop(avSafety.index[[0]])
# Out:
#                        airline avail_seat_km_per_week incidents_85_99  \
# 1                   Aer Lingus              320906734               2
# 2                    Aeroflot*             1197672318              76
# 3        Aerolineas Argentinas              385803648               6
# 4                  Aeromexico*              596871813               3
# 5                   Air Canada             1865253802               2
# 6                   Air France             3004002661              14
# 7                   Air India*              869253552               2
# 8             Air New Zealand*              710174817               3
# 9             Alaska Airlines*              965346773               5
# 10                    Alitalia              698012498               7
# 11          All Nippon Airways             1841234177               3
# 12                   American*             5228357340              21
# ...

# %%
avSafety.shape
# Out:
# (57, 8)

# %%
avSafety.head(5)
# Out:
#                  airline  avail_seat_km_per_week  incidents_85_99  \
# 0                airline  avail_seat_km_per_week  incidents_85_99
# 1             Aer Lingus               320906734                2
# 2              Aeroflot*              1197672318               76
# 3  Aerolineas Argentinas               385803648                6
# 4            Aeromexico*               596871813                3
#
#    fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 0  fatal_accidents_85_99  fatalities_85_99  incidents_00_14
# 1                      0                 0                0
# 2                     14               128                6
# 3                      0                 0                1
# 4                      1                64                5
#
#    fatal_accidents_00_14  fatalities_00_14
# 0  fatal_accidents_00_14  fatalities_00_14
# 1                      0                 0
# 2                      1                88
# ...

# %%
avSafety.tail(5)
# Out:
#                        airline avail_seat_km_per_week incidents_85_99  \
# 52       United / Continental*             7139291291              19
# 53  US Airways / America West*             2455687887              16
# 54            Vietnam Airlines              625084918               7
# 55             Virgin Atlantic             1005248585               1
# 56             Xiamen Airlines              430462962               9
#
#    fatal_accidents_85_99 fatalities_85_99 incidents_00_14  \
# 52                     8              319              14
# 53                     7              224              11
# 54                     3              171               1
# 55                     0                0               0
# 56                     1               82               2
#
#    fatal_accidents_00_14 fatalities_00_14
# 52                     2              109
# 53                     2               23
# 54                     0                0
# ...

# %%
avSafety.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   airline                 57 non-null     object
#  1   avail_seat_km_per_week  57 non-null     object
#  2   incidents_85_99         57 non-null     object
#  3   fatal_accidents_85_99   57 non-null     object
#  4   fatalities_85_99        57 non-null     object
#  5   incidents_00_14         57 non-null     object
#  6   fatal_accidents_00_14   57 non-null     object
#  7   fatalities_00_14        57 non-null     object
# dtypes: object(8)
# memory usage: 3.7+ KB

# %%
avSafety.columns
# Out:
# Index(['airline', 'avail_seat_km_per_week', 'incidents_85_99',
#        'fatal_accidents_85_99', 'fatalities_85_99', 'incidents_00_14',
#        'fatal_accidents_00_14', 'fatalities_00_14'],
#       dtype='object')

# %%
valoresPerdidos = avSafety.isnull()

# %%
for column in valoresPerdidos.columns.values.tolist():
    print(column)
    print(valoresPerdidos[column].value_counts())
    print("")
# Out:
# airline
# False    57
# Name: airline, dtype: int64
#
# avail_seat_km_per_week
# False    57
# Name: avail_seat_km_per_week, dtype: int64
#
# incidents_85_99
# False    57
# Name: incidents_85_99, dtype: int64
#
# fatal_accidents_85_99
# False    57
# Name: fatal_accidents_85_99, dtype: int64
#
# fatalities_85_99
# False    57
# Name: fatalities_85_99, dtype: int64
#
# incidents_00_14
# False    57
# Name: incidents_00_14, dtype: int64
#
# fatal_accidents_00_14
# False    57
# Name: fatal_accidents_00_14, dtype: int64
#
# fatalities_00_14
# False    57
# Name: fatalities_00_14, dtype: int64

# %%
avSafety.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   airline                 57 non-null     object
#  1   avail_seat_km_per_week  57 non-null     object
#  2   incidents_85_99         57 non-null     object
#  3   fatal_accidents_85_99   57 non-null     object
#  4   fatalities_85_99        57 non-null     object
#  5   incidents_00_14         57 non-null     object
#  6   fatal_accidents_00_14   57 non-null     object
#  7   fatalities_00_14        57 non-null     object
# dtypes: object(8)
# memory usage: 3.7+ KB

# %%
avSafety.dtypes
# Out:
# airline                   object
# avail_seat_km_per_week    object
# incidents_85_99           object
# fatal_accidents_85_99     object
# fatalities_85_99          object
# incidents_00_14           object
# fatal_accidents_00_14     object
# fatalities_00_14          object
# dtype: object

# %%
avSafety["avail_seat_km_per_week"] = pd.to_numeric(avSafety["avail_seat_km_per_week"], errors='coerce')

# %%
avSafety.dtypes
# Out:
# airline                    object
# avail_seat_km_per_week    float64
# incidents_85_99            object
# fatal_accidents_85_99      object
# fatalities_85_99           object
# incidents_00_14            object
# fatal_accidents_00_14      object
# fatalities_00_14           object
# dtype: object

# %%
avSafety["incidents_85_99"] = pd.to_numeric(avSafety["incidents_85_99"], errors='coerce')

# %%
avSafety["fatal_accidents_85_99"] = pd.to_numeric(avSafety["fatal_accidents_85_99"], errors='coerce')

# %%
avSafety["fatalities_85_99"] = pd.to_numeric(avSafety["fatalities_85_99"], errors='coerce')

# %%
avSafety["incidents_00_14"] = pd.to_numeric(avSafety["incidents_00_14"], errors='coerce')

# %%
avSafety["fatal_accidents_00_14"] = pd.to_numeric(avSafety["fatal_accidents_00_14"], errors='coerce')

# %%
avSafety["fatalities_00_14"] = pd.to_numeric(avSafety["fatalities_00_14"], errors='coerce')

# %%
avSafety.dtypes
# Out:
# airline                    object
# avail_seat_km_per_week    float64
# incidents_85_99           float64
# fatal_accidents_85_99     float64
# fatalities_85_99          float64
# incidents_00_14           float64
# fatal_accidents_00_14     float64
# fatalities_00_14          float64
# dtype: object

# %%
avSafety
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 0                      airline                     NaN              NaN
# 1                   Aer Lingus            3.209067e+08              2.0
# 2                    Aeroflot*            1.197672e+09             76.0
# 3        Aerolineas Argentinas            3.858036e+08              6.0
# 4                  Aeromexico*            5.968718e+08              3.0
# 5                   Air Canada            1.865254e+09              2.0
# 6                   Air France            3.004003e+09             14.0
# 7                   Air India*            8.692536e+08              2.0
# 8             Air New Zealand*            7.101748e+08              3.0
# 9             Alaska Airlines*            9.653468e+08              5.0
# 10                    Alitalia            6.980125e+08              7.0
# 11          All Nippon Airways            1.841234e+09              3.0
# ...

# %%
avSafety.drop(avSafety.index[[0]])
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 1                   Aer Lingus            3.209067e+08              2.0
# 2                    Aeroflot*            1.197672e+09             76.0
# 3        Aerolineas Argentinas            3.858036e+08              6.0
# 4                  Aeromexico*            5.968718e+08              3.0
# 5                   Air Canada            1.865254e+09              2.0
# 6                   Air France            3.004003e+09             14.0
# 7                   Air India*            8.692536e+08              2.0
# 8             Air New Zealand*            7.101748e+08              3.0
# 9             Alaska Airlines*            9.653468e+08              5.0
# 10                    Alitalia            6.980125e+08              7.0
# 11          All Nippon Airways            1.841234e+09              3.0
# 12                   American*            5.228357e+09             21.0
# ...

# %%
avSafety["bool_series"]= avSafety["airline"].str.isalpha()

# %%
avSafety
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 0                      airline                     NaN              NaN
# 1                   Aer Lingus            3.209067e+08              2.0
# 2                    Aeroflot*            1.197672e+09             76.0
# 3        Aerolineas Argentinas            3.858036e+08              6.0
# 4                  Aeromexico*            5.968718e+08              3.0
# 5                   Air Canada            1.865254e+09              2.0
# 6                   Air France            3.004003e+09             14.0
# 7                   Air India*            8.692536e+08              2.0
# 8             Air New Zealand*            7.101748e+08              3.0
# 9             Alaska Airlines*            9.653468e+08              5.0
# 10                    Alitalia            6.980125e+08              7.0
# 11          All Nippon Airways            1.841234e+09              3.0
# ...

# %%
dftemp = avSafety[["airline","bool_series"]]

# %%
dftemp.head(10)
# Out:
#                  airline  bool_series
# 0                airline         True
# 1             Aer Lingus        False
# 2              Aeroflot*        False
# 3  Aerolineas Argentinas        False
# 4            Aeromexico*        False
# 5             Air Canada        False
# 6             Air France        False
# 7             Air India*        False
# 8       Air New Zealand*        False
# 9       Alaska Airlines*        False

# %%
airline=('airline')

# %%
airline1=airline.replace("*", "")

# %%
dftemp.head(10)
# Out:
#                  airline  bool_series
# 0                airline         True
# 1             Aer Lingus        False
# 2              Aeroflot*        False
# 3  Aerolineas Argentinas        False
# 4            Aeromexico*        False
# 5             Air Canada        False
# 6             Air France        False
# 7             Air India*        False
# 8       Air New Zealand*        False
# 9       Alaska Airlines*        False
